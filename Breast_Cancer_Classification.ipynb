# %% [markdown]
# <a href="https://colab.research.google.com/github/Navyam-Raushan/Machine-Learning-Models/blob/main/Breast_Cancer_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA is all about analysing the Dataset
# - Using Breast cancer Data

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
breast_cancer_data = pd.read_csv('data.csv')

# %% [markdown]
# # EDA

# %%
df = breast_cancer_data
df.head()
# Out:
#          id diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0    842302         M        17.99  ...          0.4601                  0.11890          NaN
# 1    842517         M        20.57  ...          0.2750                  0.08902          NaN
# 2  84300903         M        19.69  ...          0.3613                  0.08758          NaN
# 3  84348301         M        11.42  ...          0.6638                  0.17300          NaN
# 4  84358402         M        20.29  ...          0.2364                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# - M- Malignant means dangerous
# - B- not dangerous

# %%
df["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Dropping unanmed cols- all values are missing values
df.drop(columns=['Unnamed: 32'], inplace=True, axis=1)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  ...  concave points_worst  symmetry_worst  fractal_dimension_worst
# 0    842302         M        17.99  ...                0.2654          0.4601                  0.11890
# 1    842517         M        20.57  ...                0.1860          0.2750                  0.08902
# 2  84300903         M        19.69  ...                0.2430          0.3613                  0.08758
# 3  84348301         M        11.42  ...                0.2575          0.6638                  0.17300
# 4  84358402         M        20.29  ...                0.1625          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
# Checking for datatypees
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# we will convert diagnosis so that we can able to train
# removing id cols
df.drop(columns=['id'], inplace=True, axis=1)

# %%
df.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# - To check skewness you see mean>median = Right Skewed
#
# - and if median>mean its left skewed
#
# - We need to transform the data because there is skewness in the dataset to use models like logistic regression
#
# - Google How to ahndle Skewness.

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# count   569.000000    569.000000  ...      569.000000               569.000000
# mean     14.127292     19.289649  ...        0.290076                 0.083946
# std       3.524049      4.301036  ...        0.061867                 0.018061
# min       6.981000      9.710000  ...        0.156500                 0.055040
# 25%      11.700000     16.170000  ...        0.250400                 0.071460
# 50%      13.370000     18.840000  ...        0.282200                 0.080040
# 75%      15.780000     21.800000  ...        0.317900                 0.092080
# max      28.110000     39.280000  ...        0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
# converting diagnasis col - categorical cols
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(df['diagnosis'])
df['target'] = labels
df.drop(columns=['diagnosis'], inplace=True, axis=1)

# %% [markdown]
# M -> 1 <br>
# B -> 0

# %%
df["target"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: target, Length: 569, dtype: int64

# %%
# Grouping the data based on target
df.groupby('target').mean()
# Out:
#         radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# target                             ...
# 0         12.146524     17.914762  ...        0.270246                 0.079442
# 1         17.462830     21.604906  ...        0.323468                 0.091530
#
# [2 rows x 30 columns]

# %% [markdown]
# - You can see the values for 1 values are greater its manually visible

# %%
# Let's try fitting this model without handling skewness
# With tree models and knn and logistic regression

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
X = df.drop(columns=['target'], axis=1)
y = df['target']

# %% [markdown]
# - If we need train test and val all three dataset then we need to split twice.
# - As firstly 20% is kept for test and then second time from 80% <br>
#   We keep 25% data for validation.

# %% [markdown]
# # Building the Model

# %%
X_train_temp, X_test, y_train_temp, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_temp, y_train_temp, test_size=0.25, random_state=42)

# %%
len(X_train), len(X_val), len(X_test)
# Out:
# (384, 128, 57)

# %%
y_val.value_counts(), y_test.value_counts(), y_train.value_counts()
# Out:
# (target
#  0    83
#  1    45
#  Name: count, dtype: int64,
#  target
#  0    40
#  1    17
#  Name: count, dtype: int64,
#  target
#  0    234
#  1    150
#  Name: count, dtype: int64)

# %%
# Training without handling skewness of the data firstly
# Using different models

def model_train(model, X_train, X_val, y_train, y_val):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    print(confusion_matrix(y_val, y_pred))
    print(classification_report(y_val, y_pred))

    return model

# %% [markdown]
# - Without any feature engineering doing this

# %%
knn = model_train(KNeighborsClassifier(), X_train, X_val, y_train, y_val)
# Out:
# [[77  6]
#  [ 5 40]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93        83
#            1       0.87      0.89      0.88        45
#
#     accuracy                           0.91       128
#    macro avg       0.90      0.91      0.91       128
# weighted avg       0.91      0.91      0.91       128

# %%
lr = model_train(LogisticRegression(), X_train, X_val, y_train, y_val)
# Out:
# [[77  6]
#  [ 2 43]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        83
#            1       0.88      0.96      0.91        45
#
#     accuracy                           0.94       128
#    macro avg       0.93      0.94      0.93       128
# weighted avg       0.94      0.94      0.94       128
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
clf = model_train(RandomForestClassifier(), X_train, X_val, y_train, y_val)
# Out:
# [[79  4]
#  [ 1 44]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97        83
#            1       0.92      0.98      0.95        45
#
#     accuracy                           0.96       128
#    macro avg       0.95      0.96      0.96       128
# weighted avg       0.96      0.96      0.96       128

# %%
clf.score(X_test, y_test)
# Out:
# 0.9649122807017544

# %%
lr.score(X_test, y_test)
# Out:
# 0.9649122807017544

# %%
knn.score(X_test, y_test)
# Out:
# 0.9824561403508771

# %%
# Plotting score of all three test scores
model_names = ["Logistic Regression", "KNN", "Random Forest"]
scores = [lr.score(X_test, y_test), knn.score(X_test, y_test), clf.score(X_test, y_test)]

plt.figure(figsize=(10, 6))
plt.bar(model_names, scores, color=["tomato", "skyblue", "pink"],
        edgecolor="black", width= 0.5)

plt.xlabel("Model")
plt.ylabel("Score")
plt.title("Different Model Scores Over Test Data")
# Out:
# Text(0.5, 1.0, 'Different Model Scores Over Test Data')
